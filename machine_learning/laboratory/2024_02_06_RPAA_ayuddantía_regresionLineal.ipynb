# %% [markdown]
# #Regresión lineal

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression



df = pd.read_csv('salaries.csv')
print(df.describe)
exp=df['experiencia']
salario=df['salario']

x = np.array(exp).reshape(-1, 1)
y = np.array(salario)

xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=.3, random_state=0)


regressor = LinearRegression()
regressor.fit(xtrain, ytrain)

pred = regressor.predict(xtest)


# x = np.linspace(0, 12, 100)  # Generar 100 puntos entre -5 y 5
# m = 8433.909212174  # Pendiente
# b = 26833.427381195  # Intercepto
# y = m * x + b

plt.scatter(xtrain, ytrain, color= 'red')
plt.plot(xtrain, regressor.predict(xtrain), color = 'blue')
# plt.plot(x, y, '-g')

plt.title ("Training - Regresión lineal")
plt.xlabel("Años de experiencia")
plt.ylabel("Salario")
plt.show()



plt.scatter(xtest, ytest, color= 'red')
plt.plot(xtest, pred, color = 'blue')
plt.title("Test - Regresión lineal")
plt.xlabel("Años de experiencia")
plt.ylabel("Salario")
plt.show()
# Out:
# <bound method NDFrame.describe of      experiencia  salario
# 0            1.1    39343
# 1            1.2    42774
# 2            1.3    46205
# 3            1.5    37731
# 4            2.0    43525
# ..           ...      ...
# 264          6.7    78492
# 265          7.8    90562
# 266          8.7   100613
# 267          9.9   115220
# 268         10.8   122976
#
# [269 rows x 2 columns]>

# %%
mse = mean_squared_error(ytest, pred)
r2 = r2_score(ytest, pred)
mae = mean_absolute_error(ytest, pred)
rmse = np.sqrt(mse)

# métricas para la regresión lineal
print("Métricas de evaluación del modelo de regresión lineal:")
print("MSE:", mse)
print("R2:", r2)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# Métricas de evaluación del modelo de regresión lineal:
# MSE: 27979080.532630183
# R2: 0.9584080901012524
# MAE: 4499.202991526801
# RMSE: 5289.525548915534

# %% [markdown]
# # Red neuronal

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split


xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.3, random_state=0)


model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)  # Una neurona y activación lineal
])


model.compile(optimizer='sgd', loss='mean_squared_error')  # SGD es el optimizador, mean_squared_error es la función de pérdida

model.fit(xtrain, ytrain, epochs=100, verbose=1)

loss = model.evaluate(xtest, ytest)
print("Test Loss:", loss)

predictions = model.predict(xtest)


plt.scatter(xtrain, ytrain, color= 'red')
plt.plot(xtrain, model.predict(xtrain), color = 'blue')
plt.title ("Training - Red neuronal")
plt.xlabel("Años de experiencia")
plt.ylabel("Salario")
plt.show()

plt.scatter(xtest, ytest, color='red')
plt.plot(xtest, predictions, color='blue')
plt.title("Test - Red neuronal")
plt.xlabel("Años de experiencia")
plt.ylabel("Salario")
plt.show()

print(model.evaluate(xtest,ytest))
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1233277440.0000
# Epoch 2/100
# 6/6 [==============================] - 0s 2ms/step - loss: 144856160.0000
# Epoch 3/100
# 6/6 [==============================] - 0s 3ms/step - loss: 143287072.0000
# Epoch 4/100
# 6/6 [==============================] - 0s 5ms/step - loss: 136192432.0000
# Epoch 5/100
# 6/6 [==============================] - 0s 2ms/step - loss: 129370856.0000
# Epoch 6/100
# 6/6 [==============================] - 0s 3ms/step - loss: 125561584.0000
# Epoch 7/100
# 6/6 [==============================] - 0s 3ms/step - loss: 120643504.0000
# Epoch 8/100
# 6/6 [==============================] - 0s 3ms/step - loss: 115907432.0000
# Epoch 9/100
# 6/6 [==============================] - 0s 2ms/step - loss: 112699024.0000
# Epoch 10/100
# 6/6 [==============================] - 0s 3ms/step - loss: 107713696.0000
# Epoch 11/100
# 6/6 [==============================] - 0s 2ms/step - loss: 104579184.0000
# ...

# %%
mse_nn = mean_squared_error(ytest, predictions)
r2_nn = r2_score(ytest, predictions)
mae_nn = mean_absolute_error(ytest, predictions)
rmse_nn = np.sqrt(mse_nn)

# métricas para la red neuronal
print("Métricas de evaluación del modelo de red neuronal:")
print("MSE:", mse_nn)
print("R2:", r2_nn)
print("MAE:", mae_nn)
print("RMSE:", rmse_nn)
# Out:
# Métricas de evaluación del modelo de red neuronal:
# MSE: 28524872.162131794
# R2: 0.9575967512064217
# MAE: 4604.967062114198
# RMSE: 5340.868109411783
